# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
# uncomment rows below to run on original genres

path = "less_genres.csv"
# path = 'spotify_data.csv'


data = pd.read_csv(path)
# data = data.drop('Unnamed: 0', axis=1)

# %%
data = data.drop(['track_id', 'loudness'], axis=1)
# do not think it would have much effect and the PC has very little RAM to one-hot-encode :{
data = data.drop(['artist_name', 'track_name'], axis=1)

# %%
data
# Out:
#          popularity  year    genre  danceability  energy  key  mode  \
# 0                68  2012  country         0.483   0.303    4     1
# 1                50  2012  country         0.572   0.454    3     1
# 2                57  2012  country         0.409   0.234    3     1
# 3                58  2012  country         0.392   0.251   10     1
# 4                54  2012  country         0.430   0.791    6     0
# ...             ...   ...      ...           ...     ...  ...   ...
# 1052152           4  2011  hip-hop         0.373   0.742   10     0
# 1052153           3  2011  hip-hop         0.516   0.675    7     0
# 1052154           2  2011  hip-hop         0.491   0.440    5     1
# 1052155           0  2011  hip-hop         0.480   0.405    0     1
# 1052156           3  2011  hip-hop         0.782   0.861    1     0
#
#          speechiness  acousticness  instrumentalness  liveness  valence  \
# 0             0.0429        0.6940          0.000000    0.1150   0.1390
# ...

# %%
# divide data into train and test
Y = data['genre']
X = data.drop('genre', axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.4, random_state=42)

# %%
# scaling

scaler = preprocessing.StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
model_logReg = LogisticRegression(random_state=42)
model_logReg.fit(X_train, y_train)

preds = model_logReg.predict(X_test)

# %%
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#      ambient       0.44      0.57      0.50     31191
#        blues       0.20      0.03      0.05     28448
#    classical       0.47      0.10      0.16     12883
#      country       0.28      0.35      0.31     35588
#        dance       0.35      0.46      0.40     33732
#      electro       0.39      0.72      0.50     83029
#      hip-hop       0.44      0.10      0.16     10783
#        house       0.35      0.01      0.02     15642
#        metal       0.56      0.65      0.60     32989
#     national       0.22      0.09      0.12     42526
#        opera       0.35      0.27      0.31     14782
#          pop       0.23      0.07      0.10     34273
#         rock       0.27      0.33      0.30     44997
#
#     accuracy                           0.37    420863
#    macro avg       0.35      0.29      0.27    420863
# weighted avg       0.34      0.37      0.32    420863
